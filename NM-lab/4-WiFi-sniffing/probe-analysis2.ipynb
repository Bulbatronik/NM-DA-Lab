# %%
# !apt-get install tshark
# !pip install pyshark

# %%
import os

import numpy as np
import pandas as pd

import pyshark
import nest_asyncio

# %%
nest_asyncio.apply()
cap = pyshark.FileCapture('office_capture_probes_only.pcapng')

TIMESTAMP = []
SA = []
SSID = []
RSSI = []

count = 0
successfull_packets = 0
for packet in cap:
  success = False
  count = count+1

  try:
      timestamp = packet.sniff_timestamp
      wlan_layers = packet.get_multiple_layers('wlan')
      sa = wlan_layers[0].sa
      ssid = wlan_layers[1].ssid
      rssi = packet.wlan_radio.signal_dbm
      success = True
  except:
    success = False

  if(success):
    successfull_packets = successfull_packets + 1
    TIMESTAMP.append(timestamp)
    SA.append(sa)
    SSID.append(ssid)
    RSSI.append(rssi)


print('Read: ', count)
print('Successfully processed:', successfull_packets)
# Out:
# Read:  651
# Successfully processed: 469

# %%
unique_sa = np.unique(SA)
print('There were ' +str(len(unique_sa)) + ' source MAC addresses')
# Out:
# There were 133 source MAC addresses

# %%
#The 'local bit' is the second last bit in the first byte of the MAC
#address. So, masking the first byte with '00000010' mask will return 
#the value of this local bit. if local bit is '1' then address is randomized.

def is_random_mac(sa):
  first_octet = '0x' + sa[0:2]
  first_octet = int(format(int(first_octet,16),'08b'),2)
  mask = int(format(2,'08b'),2)
  if(mask & first_octet > 0):
    return True
  else:
    return False

RANDOM_MAC = []
for sa in SA:
    RANDOM_MAC.append(is_random_mac(sa))

random_addr = 0
true_addr = 0
for sa in unique_sa:
  if is_random_mac(sa):
    random_addr+=1
  else:
    true_addr+=1

print('There were only ' +str(true_addr) + ' real MAC addresses')
# Out:
# There were only 92 real MAC addresses

# %%
# CREATE DATAFRAME
df_cap = pd.DataFrame(list(zip(TIMESTAMP,SA,SSID,RSSI,RANDOM_MAC)), columns = ['Timestamp','SA','SSID','RSSI','RANDOM_MAC'])
display(df_cap)
# Out:
#                 Timestamp                 SA  \
# 0    1521033371.663294000  02:4f:38:dd:30:12
# 1    1521033371.759730000  40:9c:28:5b:eb:aa
# 2    1521033371.769539000  40:9c:28:5b:eb:aa
# 3    1521033371.894637000  f8:63:3f:21:b4:43
# 4    1521033372.921840000  3c:2e:ff:99:25:4a
# ..                    ...                ...
# 464  1521033450.353089000  00:00:80:e7:02:48
# 465  1521033450.355215000  42:b2:cf:a9:4c:91
# 466  1521033450.508016000  40:9c:28:5b:eb:aa
# 467  1521033450.526097000  40:9c:28:5b:eb:aa
# 468  1521033451.211706000  22:aa:6f:36:f4:6d
#
#                                  SSID RSSI  RANDOM_MAC
# 0                              SSID:   -85        True
# 1                             eduroam  -81       False
# 2                             eduroam  -82       False
# 3                              SSID:   -87       False
# 4                    polimi-protected  -90       False
# ..                                ...  ...         ...
# 464                  polimi-protected  -85       False
# 465  \xef\xbf\xbd\xdPo\xef\xbf\xbd\xa  -84        True
# 466                           eduroam  -73       False
# 467                           eduroam  -74       False
# 468                            SSID:   -87        True
#
# [469 rows x 5 columns]

# %%
df_sa = df_cap.groupby(['SA'])
for sa, probes in df_sa:
  ssids = np.unique(probes['SSID'])
  rssi = probes['RSSI'].astype(float).mean()
  print(sa, rssi, ssids)
# Out:
# 00:00:00:00:00:3c -89.0 ['SSID: ']
# 00:00:80:e7:02:48 -85.0 ['polimi-protected']
# 00:19:07:95:13:a3 -86.0 ['SSID: ']
# 00:20:00:6f:02:a2 -70.88888888888889 ['SSID: ']
# 00:21:5d:c0:e4:36 -84.33333333333333 ['SSID: ']
# 00:23:6c:97:5c:39 -76.0 ['polimi-protected']
# 00:80:e7:82:b7:76 -90.0 ['eduroam']
# 02:4f:38:dd:30:12 -85.0 ['SSID: ']
# 04:d6:aa:06:e0:c6 -88.0 ['SSID: ']
# 10:02:b5:b7:8e:91 -73.25 ['SSID: ']
# 12:55:d1:80:4e:cd -84.5 ['SSID: ']
# 14:9d:09:e2:08:e8 -86.0 ['SSID: ']
# 16:c2:4b:33:1e:44 -85.66666666666667 ['SSID: ']
# 1a:3e:48:f7:83:1c -87.0 ['SSID: ']
# 1a:43:15:a4:da:72 -88.5 ['SSID: ']
# 1a:74:1c:53:42:19 -86.0 ['SSID: ']
# 20:62:74:d6:4c:5c -74.25 ['SSID: ']
# 20:62:74:d6:4c:5e -74.0 ['SSID: ']
# 22:30:74:8f:89:16 -90.0 ['SSID: ']
# 22:aa:6f:36:f4:6d -88.0 ['SSID: ']
# 24:00:ba:f9:9c:30 -79.33333333333333 ['SSID: ']
# 24:77:03:23:9d:b0 -89.0 ['ITIA-WIFI']
# 26:e6:39:c8:7a:9d -89.0 ['SSID: ']
# 28:c2:dd:29:e1:45 -87.5 ['polimi-protected']
# 28:fe:cd:18:6d:55 -85.5 ['SSID: ']
# 2c:61:f6:7a:e4:2b -72.5 ['eduroam']
# 2c:a5:ac:84:04:17 -91.0 ['SSID: ']
# 2e:8f:31:2d:f2:28 -87.0 ['SSID: ']
# 30:74:96:bd:d2:0f -81.66666666666667 ['SSID: ']
# 30:d6:c9:bd:fb:cf -89.5 ['polimi']
# 34:31:11:33:db:57 -89.83333333333333 ['eduroam' 'wifipass']
# 38:ca:da:77:ff:74 -85.75 ['eduroam']
# 3c:2e:ff:99:25:4a -89.5 ['polimi-protected']
# 40:98:ad:35:0e:d5 -85.5 ['polimi-protected']
# 40:9c:28:5b:eb:aa -81.33333333333333 ['eduroam']
# 42:b2:cf:a9:4c:91 -84.0 ['\\xef\\xbf\\xbd\\xdPo\\xef\\xbf\\xbd\\xa']
# 44:6e:e5:6f:8c:66 -87.5 ['SSID: ']
# 44:78:3e:a8:57:a1 -39.03846153846154 ['SSID: ']
# 46:03:72:14:d6:6e -86.0 ['SSID: ']
# 46:f7:94:d3:67:d0 -88.0 ['SSID: ']
# 48:13:7e:9d:41:00 -88.33333333333333 ['SSID: ' 'polimi']
# 48:43:7c:2b:6a:c7 -76.33333333333333 ['polimi-protected']
# 4c:49:e3:50:f0:40 -90.66666666666667 ['SSID: ' 'polimi-protected']
# 4c:66:41:09:59:c5 -84.2 ['SSID: ']
# 52:54:69:72:cf:99 -71.0 ['SSID: ']
# 52:c5:ed:6f:bd:ab -87.0 ['SSID: ']
# 54:8c:a0:a4:8b:f9 -82.4 ['SSID: ' 'Telecom-59707037']
# 56:55:27:07:07:ac -86.0 ['SSID: ']
# 58:3f:54:dd:11:42 -71.0 ['eduroam']
# 58:c5:cb:25:01:03 -90.5 ['awl-tec\\xef\\xbf\\xbddci' 'awl-tecnici']
# 5a:28:07:4c:d6:21 -89.0 ['SSID: ']
# 5c:0a:5b:9d:35:d5 -72.0 ['SSID: ']
# 5c:51:4f:f6:f3:bf -88.0 ['SSID: ']
# 60:fe:c5:7b:14:08 -89.0 ['polimi']
# 62:01:75:03:cf:0f -67.0 ['SSID: ']
# 64:89:e0:fd:8d:cb -53.0 ['SSID: ']
# 66:b8:a9:be:5d:b6 -87.5 ['SSID: ']
# 68:7f:74:f2:9c:ad -90.0 ['SSID: ']
# 68:94:23:4b:21:da -72.0 ['SSID: ']
# 68:a3:c4:a5:d1:38 -90.0 ['SSID: ']
# 6c:71:d9:da:18:9b -88.0 ['SSID: ']
# 6e:bb:31:a4:eb:6d -87.66666666666667 ['.WiFi Station' 'SSID: ']
# 78:4f:43:7b:92:13 -85.0 ['SSID: ']
# 78:c3:e9:cd:dc:d8 -86.53333333333333 ['SSID: '
#  'polimi-prote\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd'
#  'polimi-protected']
# 80:1f:02:fa:6a:99 -89.33333333333333 ['RPiWIFI']
# 80:1f:02:fa:7e:14 -87.5 ['RPiWIFI']
# 80:1f:02:fa:7e:15 -89.6470588235294 ['RPiWIFI' 'RPiWI\\x1e']
# 8a:93:ee:9a:80:2a -86.0 ['SSID: ']
# 8c:09:ba:cd:e8:d4 -85.0 ['|U\\x14']
# 8c:f5:a3:42:b9:85 -83.75 ['SSID: ']
# 8e:ba:c0:7a:35:9a -83.0 ['SSID: ']
# 90:61:ae:db:5b:b9 -90.0 ['polimi']
# 94:65:2d:7a:34:74 -84.66666666666667 ['SSID: ' 'polimi-protected']
# 98:5f:d3:d3:8a:10 -90.0 ['SSID: ']
# 9c:da:3e:91:5b:8b -88.6 ['SSID: ' 'WifiTR']
# a4:5e:60:ce:9f:45 -88.45454545454545 ['.WiFi Station' 'Ospiti-TIM-29966457' 'SSID: ']
# a4:5e:60:dd:8a:cb -88.5 ['eduroam']
# a4:71:74:b5:4a:93 -82.0 ['@\\xd' 'polimi-p' 'polimi-protected']
# a6:ad:7e:25:51:95 -84.0 ['SSID: ']
# a8:81:95:e0:a6:4a -83.0 ['SSID: ']
# a8:9f:ba:7b:48:d5 -90.0 ['SSID: ']
# a8:b8:6e:88:05:c7 -89.0 ['SSID: ']
# aa:4a:61:16:16:bb -87.0 ['SSID: ']
# ac:72:89:47:92:fd -73.0 ['SSID: ']
# ae:de:72:a4:dc:1a -84.0 ['SSID: ']
# b0:c5:59:5b:9b:3f -85.0 ['polimi-protected']
# b2:93:4a:32:9f:c8 -86.0 ['SSID: ']
# b4:b6:76:2a:40:fe -89.0 ['SSID: ']
# b6:b4:66:2b:e3:6f -88.0 ['SSID: ']
# b8:76:3f:c3:55:1b -86.5 ['FASTWEB-1-2F58A3' 'SSID: ']
# ba:07:e4:58:bf:1f -84.0 ['SSID: ']
# ba:2a:37:7e:7c:6e -89.0 ['SSID: ']
# bc:41:01:92:1c:5c -90.0 ['SSID: ']
# bc:e6:3f:c8:8d:f3 -86.5 ['SSID: ']
# c2:bf:1f:a4:17:17 -80.0 ['SSID: ']
# c4:43:8f:d9:84:3f -66.90322580645162 ['SSID: ']
# c4:f3:2d:8f:d2:09 -79.0 ['SSID: ']
# c6:7d:3f:d4:01:07 -82.0 ['SSID: ']
# c8:21:58:fc:d7:44 -89.0 ['SSID: ']
# c8:d7:b0:a2:2c:08 -88.0 ['SSID: ']
# cc:b0:da:63:23:44 -91.0 ['SSID: ']
# cc:b0:da:63:45:47 -88.0 ['SSID: ']
# ce:2e:23:86:9c:c7 -84.0 ['SSID: ']
# d0:51:62:e5:c0:23 -67.88888888888889 ['SSID: ']
# d0:59:e4:27:ed:14 -91.0 ['SSID: ']
# d0:81:7a:45:bc:8b -87.0 ['polimi-protected']
# d4:a1:48:3e:90:a7 -78.5 ['SSID: ' 'polimi']
# d8:c4:6a:d1:4e:d1 -83.11764705882354 ['SSID: ' 'eduroa\\xef\\xbf\\xbd' 'eduroam']
# da:a1:19:15:a8:c6 -85.0 ['SSID: ']
# da:a1:19:4d:1e:96 -88.0 ['SSID: ' 'VodafoneWiFi']
# da:a1:19:63:a8:08 -89.0 ['SSID: ']
# da:a1:19:71:f4:78 -84.5 ['SSID: ']
# da:a1:19:74:f2:1b -89.5 ['polimi']
# da:a1:19:96:6f:4b -76.33333333333333 ['SSID: ']
# da:a1:19:c5:61:97 -86.0 ['SSID: ']
# da:a1:19:f5:ef:11 -76.0 ['SSID: ']
# dc:a5:f4:cc:60:d0 -86.0 ['0021140006706f6c696d6901079618243048606c0301010706495420010d140b0504009d8d5b2a01002d1a2c181bffff0000000000000000000000000000000000000000003d16010005000000000000000000000000000000000000007f0600100000004085']
# dc:d9:16:cf:8c:b4 -89.0 ['SSID: ']
# e0:94:67:b7:75:91 -90.0 ['SSID: ']
# e0:a3:ac:84:04:17 -91.0 ['SSID: ']
# e0:ac:e3:27:51:c0 -80.0 ['\\xef\\xbf\\xbdA\\x7f\\x11\\\\xef\\xbf\\xbd#~"XxyOY\\xb"\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\x13F\\xef\\xbf\\xbd\\xef\\xbf\\xbdr\\xef\\xbf\\xbd\\xef\\xbf\\xbdH\\x1C\\xef\\xbf\\xbdN\\xf\\x14y\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\x8\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd8X6g\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd[g\\xef\\xbf\\xbdm(\\x1f\\xef\\xbf\\xbdd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd K\\x12\\x14\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd\\xef\\xbf\\xbd6']
# e4:58:e7:2c:a8:bc -72.45454545454545 ['SSID: ' 'polimi-protected']
# e4:98:d6:b0:62:46 -71.0 ['eduroam']
# e4:b3:18:31:f7:18 -90.0 ['polimi-protected']
# ec:1f:72:a8:bb:76 -77.61538461538461 ['Bambini' 'SSID: ' 'polimi-protected']
# ec:55:f9:b7:3b:c0 -89.0 ['SSID: ' 'polimi']
# ec:d3:0e:00:00:78 -76.0 ['B\\xef\\xbf\\xbd\\y\\xef\\xbf\\xbdhi']
# f4:5c:89:ad:bc:33 -87.0 ['SSID: ']
# f4:8c:50:ea:a7:c7 -83.5 ['SSID: ']
# f8:32:e4:f1:77:c6 -81.4 ['polimi-protected']
# f8:63:3f:21:b4:43 -87.0 ['SSID: ']
# f8:94:c2:e2:4c:58 -87.0 ['SSID: ']
# fe:19:70:92:ee:60 -84.5 ['SSID: ']
