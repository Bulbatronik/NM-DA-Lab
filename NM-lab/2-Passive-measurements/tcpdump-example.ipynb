# %% [markdown]
# An example on the usage of tcpdump. Let's install some useful tools firts.

# %%
# !apt-get install net-tools
# !apt-get install tcpdump
# !apt-get install iputils-ping
# !apt-get install dnsutils
# !apt-get install tshark
# !apt-get install curl

# !pip install --pre scapy[basic]
# !pip install nest_asyncio
# !pip install pyshark
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
# Fetched 196 kB in 1s (219 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 128221 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libpcap0.8
# Suggested packages:
#   apparmor
# The following NEW packages will be installed:
#   libpcap0.8 tcpdump
# 0 upgraded, 2 newly installed, 0 to remove and 19 not upgraded.
# Need to get 497 kB of archives.
# After this operation, 1,466 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libpcap0.8 amd64 1.9.1-3 [128 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 tcpdump amd64 4.9.3-4ubuntu0.1 [369 kB]
# Fetched 497 kB in 1s (423 kB/s)
# Selecting previously unselected package libpcap0.8:amd64.
# (Reading database ... 128270 files and directories currently installed.)
# Preparing to unpack .../libpcap0.8_1.9.1-3_amd64.deb ...
# Unpacking libpcap0.8:amd64 (1.9.1-3) ...
# Selecting previously unselected package tcpdump.
# Preparing to unpack .../tcpdump_4.9.3-4ubuntu0.1_amd64.deb ...
# Unpacking tcpdump (4.9.3-4ubuntu0.1) ...
# Setting up libpcap0.8:amd64 (1.9.1-3) ...
# Setting up tcpdump (4.9.3-4ubuntu0.1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   iputils-ping
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 40.1 kB of archives.
# After this operation, 108 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 iputils-ping amd64 3:20190709-3 [40.1 kB]
# Fetched 40.1 kB in 1s (63.4 kB/s)
# Selecting previously unselected package iputils-ping.
# (Reading database ... 128293 files and directories currently installed.)
# Preparing to unpack .../iputils-ping_3%3a20190709-3_amd64.deb ...
# Unpacking iputils-ping (3:20190709-3) ...
# Setting up iputils-ping (3:20190709-3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   bind9-dnsutils bind9-host bind9-libs libmaxminddb0
# Suggested packages:
#   mmdb-bin
# The following NEW packages will be installed:
#   bind9-dnsutils bind9-host bind9-libs dnsutils libmaxminddb0
# 0 upgraded, 5 newly installed, 0 to remove and 19 not upgraded.
# Need to get 1,315 kB of archives.
# After this operation, 4,190 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmaxminddb0 amd64 1.4.2-0ubuntu1.20.04.1 [26.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bind9-libs amd64 1:9.16.1-0ubuntu2.12 [1,109 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bind9-host amd64 1:9.16.1-0ubuntu2.12 [43.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bind9-dnsutils amd64 1:9.16.1-0ubuntu2.12 [134 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 dnsutils all 1:9.16.1-0ubuntu2.12 [2,764 B]
# Fetched 1,315 kB in 1s (983 kB/s)
# Selecting previously unselected package libmaxminddb0:amd64.
# (Reading database ... 128303 files and directories currently installed.)
# Preparing to unpack .../libmaxminddb0_1.4.2-0ubuntu1.20.04.1_amd64.deb ...
# Unpacking libmaxminddb0:amd64 (1.4.2-0ubuntu1.20.04.1) ...
# Selecting previously unselected package bind9-libs:amd64.
# Preparing to unpack .../bind9-libs_1%3a9.16.1-0ubuntu2.12_amd64.deb ...
# Unpacking bind9-libs:amd64 (1:9.16.1-0ubuntu2.12) ...
# Selecting previously unselected package bind9-host.
# Preparing to unpack .../bind9-host_1%3a9.16.1-0ubuntu2.12_amd64.deb ...
# Unpacking bind9-host (1:9.16.1-0ubuntu2.12) ...
# Selecting previously unselected package bind9-dnsutils.
# Preparing to unpack .../bind9-dnsutils_1%3a9.16.1-0ubuntu2.12_amd64.deb ...
# Unpacking bind9-dnsutils (1:9.16.1-0ubuntu2.12) ...
# Selecting previously unselected package dnsutils.
# Preparing to unpack .../dnsutils_1%3a9.16.1-0ubuntu2.12_all.deb ...
# Unpacking dnsutils (1:9.16.1-0ubuntu2.12) ...
# Setting up libmaxminddb0:amd64 (1.4.2-0ubuntu1.20.04.1) ...
# Setting up bind9-libs:amd64 (1:9.16.1-0ubuntu2.12) ...
# Setting up bind9-host (1:9.16.1-0ubuntu2.12) ...
# Setting up bind9-dnsutils (1:9.16.1-0ubuntu2.12) ...
# Setting up dnsutils (1:9.16.1-0ubuntu2.12) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libc-ares2 liblua5.2-0 libnl-genl-3-200 libsbc1 libsmi2ldbl libspandsp2
#   libspeexdsp1 libwireshark-data libwireshark13 libwiretap10 libwsutil11
#   wireshark-common
# Suggested packages:
#   snmp-mibs-downloader geoipupdate geoip-database geoip-database-extra
#   libjs-leaflet libjs-leaflet.markercluster wireshark-doc
# The following NEW packages will be installed:
#   libc-ares2 liblua5.2-0 libnl-genl-3-200 libsbc1 libsmi2ldbl libspandsp2
#   libspeexdsp1 libwireshark-data libwireshark13 libwiretap10 libwsutil11
#   tshark wireshark-common
# 0 upgraded, 13 newly installed, 0 to remove and 19 not upgraded.
# Need to get 18.1 MB of archives.
# After this operation, 106 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 liblua5.2-0 amd64 5.2.4-1.1build3 [106 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libnl-genl-3-200 amd64 3.4.0-1ubuntu0.1 [11.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsmi2ldbl amd64 0.4.8+dfsg2-16 [100 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libspeexdsp1 amd64 1.2~rc1.2-1.1ubuntu1.20.04.1 [40.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libwireshark-data all 3.2.3-1 [1,456 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libc-ares2 amd64 1.15.0-1ubuntu0.1 [38.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libsbc1 amd64 1.4-1 [31.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 libwsutil11 amd64 3.2.3-1 [61.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/universe amd64 libwiretap10 amd64 3.2.3-1 [199 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 libwireshark13 amd64 3.2.3-1 [15.2 MB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 wireshark-common amd64 3.2.3-1 [441 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/universe amd64 tshark amd64 3.2.3-1 [137 kB]
# Fetched 18.1 MB in 4s (4,979 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package liblua5.2-0:amd64.
# (Reading database ... 128355 files and directories currently installed.)
# Preparing to unpack .../00-liblua5.2-0_5.2.4-1.1build3_amd64.deb ...
# Unpacking liblua5.2-0:amd64 (5.2.4-1.1build3) ...
# Selecting previously unselected package libnl-genl-3-200:amd64.
# Preparing to unpack .../01-libnl-genl-3-200_3.4.0-1ubuntu0.1_amd64.deb ...
# Unpacking libnl-genl-3-200:amd64 (3.4.0-1ubuntu0.1) ...
# Selecting previously unselected package libsmi2ldbl:amd64.
# Preparing to unpack .../02-libsmi2ldbl_0.4.8+dfsg2-16_amd64.deb ...
# Unpacking libsmi2ldbl:amd64 (0.4.8+dfsg2-16) ...
# Selecting previously unselected package libspandsp2:amd64.
# Preparing to unpack .../03-libspandsp2_0.0.6+dfsg-2_amd64.deb ...
# Unpacking libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Selecting previously unselected package libspeexdsp1:amd64.
# Preparing to unpack .../04-libspeexdsp1_1.2~rc1.2-1.1ubuntu1.20.04.1_amd64.deb ...
# Unpacking libspeexdsp1:amd64 (1.2~rc1.2-1.1ubuntu1.20.04.1) ...
# Selecting previously unselected package libwireshark-data.
# Preparing to unpack .../05-libwireshark-data_3.2.3-1_all.deb ...
# Unpacking libwireshark-data (3.2.3-1) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../06-libc-ares2_1.15.0-1ubuntu0.1_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# Selecting previously unselected package libsbc1:amd64.
# Preparing to unpack .../07-libsbc1_1.4-1_amd64.deb ...
# Unpacking libsbc1:amd64 (1.4-1) ...
# Selecting previously unselected package libwsutil11:amd64.
# Preparing to unpack .../08-libwsutil11_3.2.3-1_amd64.deb ...
# Unpacking libwsutil11:amd64 (3.2.3-1) ...
# Selecting previously unselected package libwiretap10:amd64.
# Preparing to unpack .../09-libwiretap10_3.2.3-1_amd64.deb ...
# Unpacking libwiretap10:amd64 (3.2.3-1) ...
# Selecting previously unselected package libwireshark13:amd64.
# Preparing to unpack .../10-libwireshark13_3.2.3-1_amd64.deb ...
# Unpacking libwireshark13:amd64 (3.2.3-1) ...
# Selecting previously unselected package wireshark-common.
# Preparing to unpack .../11-wireshark-common_3.2.3-1_amd64.deb ...
# Unpacking wireshark-common (3.2.3-1) ...
# Selecting previously unselected package tshark.
# Preparing to unpack .../12-tshark_3.2.3-1_amd64.deb ...
# Unpacking tshark (3.2.3-1) ...
# Setting up libsbc1:amd64 (1.4-1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# Setting up libwsutil11:amd64 (3.2.3-1) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libsmi2ldbl:amd64 (0.4.8+dfsg2-16) ...
# Setting up libwiretap10:amd64 (3.2.3-1) ...
# Setting up libwireshark-data (3.2.3-1) ...
# Setting up liblua5.2-0:amd64 (5.2.4-1.1build3) ...
# Setting up libnl-genl-3-200:amd64 (3.4.0-1ubuntu0.1) ...
# Setting up libspeexdsp1:amd64 (1.2~rc1.2-1.1ubuntu1.20.04.1) ...
# Setting up libwireshark13:amd64 (3.2.3-1) ...
# Setting up wireshark-common (3.2.3-1) ...
# Setting up tshark (3.2.3-1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for shared-mime-info (1.15-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# curl is already the newest version (7.68.0-1ubuntu2.16).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scapy[basic]
#   Downloading scapy-2.5.0.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from scapy[basic]) (7.9.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->scapy[basic]) (57.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->scapy[basic]) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->scapy[basic]) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->scapy[basic]) (5.7.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->scapy[basic]) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->scapy[basic]) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->scapy[basic]) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->scapy[basic]) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->scapy[basic]) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->scapy[basic]) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->scapy[basic]) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->scapy[basic]) (0.7.0)
# Building wheels for collected packages: scapy
#   Building wheel for scapy (setup.py) ... done
#   Created wheel for scapy: filename=scapy-2.5.0-py2.py3-none-any.whl size=1444349 sha256=d5f401588a676451c50b996f17624b1db6bac457b13c20059e5ce266e4c97b49
#   Stored in directory: /root/.cache/pip/wheels/98/ea/08/164e840ab2c83b892bf8b193ce9d92d029dc3e5f2b75319953
# Successfully built scapy
# Installing collected packages: scapy, jedi
# Successfully installed jedi-0.18.2 scapy-2.5.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyshark
#   Downloading pyshark-0.5.3-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 KB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from pyshark) (23.0)
# Requirement already satisfied: py in /usr/local/lib/python3.8/dist-packages (from pyshark) (1.11.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.8/dist-packages (from pyshark) (1.4.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pyshark) (4.9.2)
# Installing collected packages: pyshark
# Successfully installed pyshark-0.5.3

# %% [markdown]
# Let's see what network interfaces are available on the virtual machine

# %%
# !ifconfig

# %% [markdown]
# It seems only one ethernet network interface is available (lo is the loopback interface). Let's start a tcpdump capture and see what happens

# %%
# !tcpdump -i eth0

# %% [markdown]
# Kind of a mess, right? And we are on a VM doing basically nothing (imagine what happens when you monitor a working connected system). This gives you an idea of the massive amount of data to be analyzed with passive monitoring approaches.
#
# Luckily, we can make use of packet filters to reduce a bit the number of packets to capture. As an example, let's see if there is UDP traffic...

# %%
# !tcpdump -i eth0 udp

# %% [markdown]
# It seems that there is no significant UDP traffic! Let's try to produce some: we'll ask a DNS server the address of a website (e.g., www.gazzetta.it)
#
# Some tricks used here:
#
#
# *   I use dig <url> for making a DNS call and retrieve the IP address. Note that DNS uses UDP on port 53.
# *   To launch tcpdump and dig at the same time, I use the & operator (run in background). To make sure to capture traffic, I'm postponing the DNS query by 5 seconds with the sleep command.
# *   I'll use the -nn option for tcpdump not to resolve addresses and hostnames
# *   I'll redirect the output of dig on /dev/null to have a clearer output (we'll see only the tcpdump output)

# %%
# !tcpdump -i eth0 -nn udp & (sleep 5; dig www.gazzetta.it > /dev/null)

# %% [markdown]
# OK! Now an exercise for you. Let's try to capture some ICMP traffic.

# %%
# !tcpdump -i eth0 -nn icmp & (sleep 5; ping www.gazzetta.it -c 10 > /dev/null)

# %% [markdown]
# Now let's try to make some web browsing (I'll use curl). I'll visit the FIRST website ever created

# %%
# !curl http://info.cern.ch/

# %% [markdown]
# And let's see what's behind it.  First I'll retrieve the IP address of the cern server. Then I'm going to tcpdump asking only for TCP traffic in/outgoing the CERN server.

# %%
# !dig info.cern.ch

# %%
# !tcpdump -i eth0 -nn 'tcp and host 188.184.21.108' & (sleep 5; curl -s 'http://info.cern.ch/' > /dev/null)

# %% [markdown]
# We can also ask tcpdump to be more verbose and inspect packet payload with the -X option (we're actually doing a deep packet inspection here!).

# %%
# !tcpdump -i eth0 -nnX 'tcp and host 188.184.21.108' & (sleep 5; curl -s 'http://info.cern.ch/' > /dev/null)

# %% [markdown]
# To write the output on a pcap file, we can use the -w option

# %%
# !tcpdump -i eth0 -nnX 'tcp and host 188.184.21.108' -w 'http_capture.pcap' & (sleep 5; curl -s 'http://info.cern.ch/' > /dev/null)

# %% [markdown]
# Good! Now we have the 'http_capture.pcap' file in our local folder. We can open it with python and analyze its content autmoatically, e.g., via scapy!

# %%
import os

import pyshark
import nest_asyncio
import pandas as pd

from scapy.all import *

# %%
cap = rdpcap('http_capture.pcap')
for packet in cap:
  packet.show()

# %% [markdown]
# Similarly, we can use the python pyshark library for doing the same.

# %%
nest_asyncio.apply()
cap = pyshark.FileCapture('http_capture.pcap')
for packet in cap:
  print(packet)
cap.close()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.8/dist-packages (1.5.6)
# Packet (Length: 74)
# Layer ETH:
# 	Destination: 02:42:dc:86:e1:4f
# 	Address: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:ac:1c:00:0c
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 60
# 	Identification: 0x561a (22042)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 64
# 	Protocol: TCP (6)
# 	Header checksum: 0x6655 [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 172.28.0.12
# 	Destination: 188.184.21.108
# Layer TCP:
# 	Source Port: 34966
# 	Destination Port: 80
# 	Stream index: 0
# 	TCP Segment Len: 0
# 	Sequence number: 0    (relative sequence number)
# 	Sequence number (raw): 351902455
# 	Next sequence number: 1    (relative sequence number)
# 	Acknowledgment number: 0
# 	Acknowledgment number (raw): 0
# 	1010 .... = Header Length: 40 bytes (10)
# 	Flags: 0x002 (SYN)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...0 .... = Acknowledgment: Not set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..1. = Syn: Set
# 	Expert Info (Chat/Sequence): Connection establish request (SYN): server port 80
# 	Connection establish request (SYN): server port 80
# 	Severity level: Chat
# 	Group: Sequence
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7S\xc2\xb7
# 	Window size value: 64240
# 	Calculated window size: 64240
# 	Checksum: 0x7e7b [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (20 bytes), Maximum segment size, SACK permitted, Timestamps, No-Operation (NOP), Window scale
# 	TCP Option - Maximum segment size: 1460 bytes
# 	Kind: Maximum Segment Size (2)
# 	Length: 4
# 	MSS Value: 1460
# 	TCP Option - SACK permitted
# 	TCP Option - Timestamps: TSval 3909608073, TSecr 0
# 	Timestamp value: 3909608073
# 	Timestamp echo reply: 0
# 	TCP Option - No-Operation (NOP)
# 	TCP Option - Window scale: 7 (multiply by 128)
# 	Shift count: 7
# 	Multiplier: 128
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000000000 seconds
# 	Time since previous frame in this TCP stream: 0.000000000 seconds
# 	Kind: SACK Permitted (4)
# 	Kind: Time Stamp Option (8)
# 	Kind: No-Operation (1)
# 	Kind: Window Scale (3)
# 	Length: 2
# 	Length: 10
# 	Length: 3
#
# Packet (Length: 74)
# Layer ETH:
# 	Destination: 02:42:ac:1c:00:0c
# 	Address: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:dc:86:e1:4f
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 60
# 	Identification: 0x0000 (0)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 56
# 	Protocol: TCP (6)
# 	Header checksum: 0xc46f [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 188.184.21.108
# 	Destination: 172.28.0.12
# Layer TCP:
# 	Source Port: 80
# 	Destination Port: 34966
# 	Stream index: 0
# 	TCP Segment Len: 0
# 	Sequence number: 0    (relative sequence number)
# 	Sequence number (raw): 1192282606
# 	Next sequence number: 1    (relative sequence number)
# 	Acknowledgment number: 1    (relative ack number)
# 	Acknowledgment number (raw): 351902456
# 	1010 .... = Header Length: 40 bytes (10)
# 	Flags: 0x012 (SYN, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..1. = Syn: Set
# 	Expert Info (Chat/Sequence): Connection establish acknowledge (SYN+ACK): server port 80
# 	Connection establish acknowledge (SYN+ACK): server port 80
# 	Severity level: Chat
# 	Group: Sequence
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7A\xc2\xb7\xc2\xb7S\xc2\xb7
# 	Window size value: 28960
# 	Calculated window size: 28960
# 	Checksum: 0x05cb [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (20 bytes), Maximum segment size, SACK permitted, Timestamps, No-Operation (NOP), Window scale
# 	TCP Option - Maximum segment size: 1460 bytes
# 	Kind: Maximum Segment Size (2)
# 	Length: 4
# 	MSS Value: 1460
# 	TCP Option - SACK permitted
# 	TCP Option - Timestamps: TSval 1676138855, TSecr 3909608073
# 	Timestamp value: 1676138855
# 	Timestamp echo reply: 3909608073
# 	TCP Option - No-Operation (NOP)
# 	TCP Option - Window scale: 7 (multiply by 128)
# 	Shift count: 7
# 	Multiplier: 128
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 1
# 	The RTT to ACK the segment was: 0.110651000 seconds
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.110651000 seconds
# 	Time since previous frame in this TCP stream: 0.110651000 seconds
# 	Kind: SACK Permitted (4)
# 	Kind: Time Stamp Option (8)
# 	Kind: No-Operation (1)
# 	Kind: Window Scale (3)
# 	Length: 2
# 	Length: 10
# 	Length: 3
#
# Packet (Length: 66)
# Layer ETH:
# 	Destination: 02:42:dc:86:e1:4f
# 	Address: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:ac:1c:00:0c
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 52
# 	Identification: 0x561b (22043)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 64
# 	Protocol: TCP (6)
# 	Header checksum: 0x665c [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 172.28.0.12
# 	Destination: 188.184.21.108
# Layer TCP:
# 	Source Port: 34966
# 	Destination Port: 80
# 	Stream index: 0
# 	TCP Segment Len: 0
# 	Sequence number: 1    (relative sequence number)
# 	Sequence number (raw): 351902456
# 	Next sequence number: 1    (relative sequence number)
# 	Acknowledgment number: 1    (relative ack number)
# 	Acknowledgment number (raw): 1192282607
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7A\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7
# 	Window size value: 502
# 	Calculated window size: 64256
# 	Window size scaling factor: 128
# 	Checksum: 0x7e73 [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 3909608184, TSecr 1676138855
# 	Length: 10
# 	Timestamp value: 3909608184
# 	Timestamp echo reply: 1676138855
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 2
# 	The RTT to ACK the segment was: 0.000085000 seconds
# 	iRTT: 0.110736000 seconds
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.110736000 seconds
# 	Time since previous frame in this TCP stream: 0.000085000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
#
# Packet (Length: 142)
# Layer ETH:
# 	Destination: 02:42:dc:86:e1:4f
# 	Address: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:ac:1c:00:0c
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 128
# 	Identification: 0x561c (22044)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 64
# 	Protocol: TCP (6)
# 	Header checksum: 0x660f [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 172.28.0.12
# 	Destination: 188.184.21.108
# Layer TCP:
# 	Source Port: 34966
# 	Destination Port: 80
# 	Stream index: 0
# 	TCP Segment Len: 76
# 	Sequence number: 1    (relative sequence number)
# 	Sequence number (raw): 351902456
# 	Next sequence number: 77    (relative sequence number)
# 	Acknowledgment number: 1    (relative ack number)
# 	Acknowledgment number (raw): 1192282607
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7AP\xc2\xb7\xc2\xb7\xc2\xb7
# 	Window size value: 502
# 	Calculated window size: 64256
# 	Window size scaling factor: 128
# 	Checksum: 0x7ebf [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 3909608184, TSecr 1676138855
# 	Length: 10
# 	Timestamp value: 3909608184
# 	Timestamp echo reply: 1676138855
# 	SEQ/ACK analysis
# 	iRTT: 0.110736000 seconds
# 	Bytes in flight: 76
# 	Bytes sent since last PSH flag: 76
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.110877000 seconds
# 	Time since previous frame in this TCP stream: 0.000141000 seconds
# 	TCP payload (76 bytes)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# Layer HTTP:
# 	GET / HTTP/1.1\r\n
# 	Expert Info (Chat/Sequence): GET / HTTP/1.1\r\n
# 	GET / HTTP/1.1\r\n
# 	Severity level: Chat
# 	Group: Sequence
# 	Request Method: GET
# 	Request URI: /
# 	Request Version: HTTP/1.1
# 	Host: info.cern.ch\r\n
# 	User-Agent: curl/7.68.0\r\n
# 	Accept: */*\r\n
# 	Full request URI: http://info.cern.ch/
# 	HTTP request 1/1
# 	\r\n
#
# Packet (Length: 66)
# Layer ETH:
# 	Destination: 02:42:ac:1c:00:0c
# 	Address: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:dc:86:e1:4f
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 52
# 	Identification: 0x1038 (4152)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 56
# 	Protocol: TCP (6)
# 	Header checksum: 0xb43f [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 188.184.21.108
# 	Destination: 172.28.0.12
# Layer TCP:
# 	Source Port: 80
# 	Destination Port: 34966
# 	Stream index: 0
# 	TCP Segment Len: 0
# 	Sequence number: 1    (relative sequence number)
# 	Sequence number (raw): 1192282607
# 	Next sequence number: 1    (relative sequence number)
# 	Acknowledgment number: 77    (relative ack number)
# 	Acknowledgment number (raw): 351902532
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7A\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7
# 	Window size value: 227
# 	Calculated window size: 29056
# 	Window size scaling factor: 128
# 	Checksum: 0xa3a9 [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 1676138967, TSecr 3909608184
# 	Length: 10
# 	Timestamp value: 1676138967
# 	Timestamp echo reply: 3909608184
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 4
# 	The RTT to ACK the segment was: 0.108446000 seconds
# 	iRTT: 0.110736000 seconds
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.219323000 seconds
# 	Time since previous frame in this TCP stream: 0.108446000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
#
# Packet (Length: 944)
# Layer ETH:
# 	Destination: 02:42:ac:1c:00:0c
# 	Address: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:dc:86:e1:4f
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 930
# 	Identification: 0x1039 (4153)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 56
# 	Protocol: TCP (6)
# 	Header checksum: 0xb0d0 [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 188.184.21.108
# 	Destination: 172.28.0.12
# Layer TCP:
# 	Source Port: 80
# 	Destination Port: 34966
# 	Stream index: 0
# 	TCP Segment Len: 878
# 	Sequence number: 1    (relative sequence number)
# 	Sequence number (raw): 1192282607
# 	Next sequence number: 879    (relative sequence number)
# 	Acknowledgment number: 77    (relative ack number)
# 	Acknowledgment number (raw): 351902532
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7AP\xc2\xb7\xc2\xb7\xc2\xb7
# 	Window size value: 227
# 	Calculated window size: 29056
# 	Window size scaling factor: 128
# 	Checksum: 0x3331 [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 1676138967, TSecr 3909608184
# 	Length: 10
# 	Timestamp value: 1676138967
# 	Timestamp echo reply: 3909608184
# 	SEQ/ACK analysis
# 	iRTT: 0.110736000 seconds
# 	Bytes in flight: 878
# 	Bytes sent since last PSH flag: 878
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.220540000 seconds
# 	Time since previous frame in this TCP stream: 0.001217000 seconds
# 	TCP payload (878 bytes)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# Layer HTTP:
# 	HTTP/1.1 200 OK\r\n
# 	Expert Info (Chat/Sequence): HTTP/1.1 200 OK\r\n
# 	HTTP/1.1 200 OK\r\n
# 	Severity level: Chat
# 	Group: Sequence
# 	Response Version: HTTP/1.1
# 	Status Code: 200
# 	Status Code Description: OK
# 	Response Phrase: OK
# 	Date: Wed, 01 Mar 2023 21:05:05 GMT\r\n
# 	Server: Apache\r\n
# 	Last-Modified: Wed, 05 Feb 2014 16:00:31 GMT\r\n
# 	Content-Length: 646\r\n
# 	Content length: 646
# 	Connection: close\r\n
# 	Content-Type: text/html\r\n
# 	HTTP response 1/1
# 	Time since request: 0.109663000 seconds
# 	Request in frame: 4
# 	Request URI: http://info.cern.ch/
# 	File Data: 646 bytes
# 	\r\n
# 	ETag: "286-4f1aadb3105c0"\r\n
# 	Accept-Ranges: bytes\r\n
# Layer DATA-TEXT-LINES:
# 	<html><head></head><body><header>\n
# 	<title>http://info.cern.ch</title>\n
# 	</header>\n
# 	\n
# 	<h1>http://info.cern.ch - home of the first website</h1>\n
# 	<p>From here you can:</p>\n
# 	<ul>\n
# 	<li><a href="http://info.cern.ch/hypertext/WWW/TheProject.html">Browse the first website</a></li>\n
# 	<li><a href="http://line-mode.cern.ch/www/hypertext/WWW/TheProject.html">Browse the first website using the line-mode browser simulator</a></li>\n
# 	<li><a href="http://home.web.cern.ch/topics/birth-web">Learn about the birth of the web</a></li>\n
# 	<li><a href="http://home.web.cern.ch/about">Learn about CERN, the physics laboratory where the web was born</a></li>\n
# 	</ul>\n
# 	</body></html>\n
# /usr/local/lib/python3.8/dist-packages/pyshark/packet/layers/xml_layer.py:26: RuntimeWarning: coroutine 'Capture._get_tshark_process' was never awaited
#   attributes = dict(field.attrib)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Packet (Length: 66)
# Layer ETH:
# 	Destination: 02:42:dc:86:e1:4f
# 	Address: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:ac:1c:00:0c
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 52
# 	Identification: 0x561d (22045)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 64
# 	Protocol: TCP (6)
# 	Header checksum: 0x665a [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 172.28.0.12
# 	Destination: 188.184.21.108
# Layer TCP:
# 	Source Port: 34966
# 	Destination Port: 80
# 	Stream index: 0
# 	TCP Segment Len: 0
# 	Sequence number: 77    (relative sequence number)
# 	Sequence number (raw): 351902532
# 	Next sequence number: 77    (relative sequence number)
# 	Acknowledgment number: 879    (relative ack number)
# 	Acknowledgment number (raw): 1192283485
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7A\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7
# 	Window size value: 496
# 	Calculated window size: 63488
# 	Window size scaling factor: 128
# 	Checksum: 0x7e73 [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 3909608294, TSecr 1676138967
# 	Length: 10
# 	Timestamp value: 3909608294
# 	Timestamp echo reply: 1676138967
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 6
# 	The RTT to ACK the segment was: 0.000034000 seconds
# 	iRTT: 0.110736000 seconds
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.220574000 seconds
# 	Time since previous frame in this TCP stream: 0.000034000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
#
# Packet (Length: 66)
# Layer ETH:
# 	Destination: 02:42:ac:1c:00:0c
# 	Address: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:dc:86:e1:4f
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 52
# 	Identification: 0x103a (4154)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 56
# 	Protocol: TCP (6)
# 	Header checksum: 0xb43d [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 188.184.21.108
# 	Destination: 172.28.0.12
# Layer TCP:
# 	Source Port: 80
# 	Destination Port: 34966
# 	Stream index: 0
# 	TCP Segment Len: 0
# 	Sequence number: 879    (relative sequence number)
# 	Sequence number (raw): 1192283485
# 	Next sequence number: 880    (relative sequence number)
# 	Acknowledgment number: 77    (relative ack number)
# 	Acknowledgment number (raw): 351902532
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x011 (FIN, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...1 = Fin: Set
# 	Expert Info (Chat/Sequence): Connection finish (FIN)
# 	Connection finish (FIN)
# 	Severity level: Chat
# 	Group: Sequence
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7A\xc2\xb7\xc2\xb7\xc2\xb7F
# 	Window size value: 227
# 	Calculated window size: 29056
# 	Window size scaling factor: 128
# 	Checksum: 0xa03a [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 1676138967, TSecr 3909608184
# 	Length: 10
# 	Timestamp value: 1676138967
# 	Timestamp echo reply: 3909608184
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.220542000 seconds
# 	Time since previous frame in this TCP stream: -0.000032000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
#
# Packet (Length: 66)
# Layer ETH:
# 	Destination: 02:42:dc:86:e1:4f
# 	Address: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:ac:1c:00:0c
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 52
# 	Identification: 0x561e (22046)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 64
# 	Protocol: TCP (6)
# 	Header checksum: 0x6659 [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 172.28.0.12
# 	Destination: 188.184.21.108
# Layer TCP:
# 	Source Port: 34966
# 	Destination Port: 80
# 	Stream index: 0
# 	TCP Segment Len: 0
# 	Sequence number: 77    (relative sequence number)
# 	Sequence number (raw): 351902532
# 	Next sequence number: 78    (relative sequence number)
# 	Acknowledgment number: 880    (relative ack number)
# 	Acknowledgment number (raw): 1192283486
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x011 (FIN, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...1 = Fin: Set
# 	Expert Info (Chat/Sequence): Connection finish (FIN)
# 	Connection finish (FIN)
# 	Severity level: Chat
# 	Group: Sequence
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7A\xc2\xb7\xc2\xb7\xc2\xb7F
# 	Window size value: 501
# 	Calculated window size: 64128
# 	Window size scaling factor: 128
# 	Checksum: 0x7e73 [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 3909608294, TSecr 1676138967
# 	Length: 10
# 	Timestamp value: 3909608294
# 	Timestamp echo reply: 1676138967
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 8
# 	The RTT to ACK the segment was: 0.000204000 seconds
# 	iRTT: 0.110736000 seconds
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.220746000 seconds
# 	Time since previous frame in this TCP stream: 0.000204000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
#
# Packet (Length: 66)
# Layer ETH:
# 	Destination: 02:42:ac:1c:00:0c
# 	Address: 02:42:ac:1c:00:0c
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 02:42:dc:86:e1:4f
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 02:42:dc:86:e1:4f
# Layer IP:
# 	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 52
# 	Identification: 0x103b (4155)
# 	Flags: 0x4000, Don't fragment
# 	0... .... .... .... = Reserved bit: Not set
# 	.1.. .... .... .... = Don't fragment: Set
# 	..0. .... .... .... = More fragments: Not set
# 	Fragment offset: 0
# 	Time to live: 56
# 	Protocol: TCP (6)
# 	Header checksum: 0xb43c [validation disabled]
# 	Header checksum status: Unverified
# 	Source: 188.184.21.108
# 	Destination: 172.28.0.12
# Layer TCP:
# 	Source Port: 80
# 	Destination Port: 34966
# 	Stream index: 0
# 	TCP Segment Len: 0
# 	Sequence number: 880    (relative sequence number)
# 	Sequence number (raw): 1192283486
# 	Next sequence number: 880    (relative sequence number)
# 	Acknowledgment number: 78    (relative ack number)
# 	Acknowledgment number (raw): 351902533
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Nonce: Not set
# 	.... 0... .... = Congestion Window Reduced (CWR): Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: \xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7A\xc2\xb7\xc2\xb7\xc2\xb7\xc2\xb7
# 	Window size value: 227
# 	Calculated window size: 29056
# 	Window size scaling factor: 128
# 	Checksum: 0x9f5e [unverified]
# 	Checksum Status: Unverified
# 	Urgent pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 1676139076, TSecr 3909608294
# 	Length: 10
# 	Timestamp value: 1676139076
# 	Timestamp echo reply: 3909608294
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 9
# 	The RTT to ACK the segment was: 0.107879000 seconds
# 	iRTT: 0.110736000 seconds
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.328625000 seconds
# 	Time since previous frame in this TCP stream: 0.107879000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)

# %% [markdown]
# Let's see some powerful features of pyshark

# %%
nest_asyncio.apply()
cap = pyshark.FileCapture('http_capture.pcap')
for packet in cap:
  print('From: ' + packet.ip.src + ':' + packet.tcp.srcport +' To: '+ packet.ip.dst + ':' + packet.tcp.dstport + ', ' + packet.length + ' bytes')
# Out:
# From: 172.28.0.12:34966 To: 188.184.21.108:80, 74 bytes
# From: 188.184.21.108:80 To: 172.28.0.12:34966, 74 bytes
# From: 172.28.0.12:34966 To: 188.184.21.108:80, 66 bytes
# From: 172.28.0.12:34966 To: 188.184.21.108:80, 142 bytes
# From: 188.184.21.108:80 To: 172.28.0.12:34966, 66 bytes
# From: 188.184.21.108:80 To: 172.28.0.12:34966, 944 bytes
# From: 172.28.0.12:34966 To: 188.184.21.108:80, 66 bytes
# From: 188.184.21.108:80 To: 172.28.0.12:34966, 66 bytes
# From: 172.28.0.12:34966 To: 188.184.21.108:80, 66 bytes
# From: 188.184.21.108:80 To: 172.28.0.12:34966, 66 bytes

# %% [markdown]
# Ok! Now let's try an exercise. Let's see what kind of traffic the VM is exchanging when idle. We'll use tcpdump for monitoring say 5 minutes of traffic and process the resulting pcap file automatically with pyshark!!
#
# Let's say we want to reproduce the Wireshark 'conversations' tab, which summarizes the following information for each flow (identified by the 5-tuple ipa,ipb,porta,portb,protocol) like this:
#
# *   ADDRESS A
# *   PORT A
# *   ADDRESS B
# *   PORT B
# *   BYTES
# *   PACKETS

# %%
# !tcpdump -G 300 -W 1 -w 'tcp_capture.pcap' -i eth0 'tcp'
# Out:
# tcpdump: listening on eth0, link-type EN10MB (Ethernet), capture size 262144 bytes
# Maximum file limit reached: 1
# 700 packets captured
# 709 packets received by filter
# 0 packets dropped by kernel

# %%
nest_asyncio.apply()
cap = pyshark.FileCapture('tcp_capture.pcap')

INDEXES = [];
CONVERSATIONS = {'address_a': [], 'address_b': [], 'port_a': [], 'port_b': [], 'bytes': [], 'packets': [], 'start': [],'duration': []};

for packet in cap:
  
  address_a = packet.ip.src
  address_b = packet.ip.dst
  port_a = packet.tcp.srcport
  port_b = packet.tcp.dstport
  packet_bytes = packet.length
  packet_timestamp = packet.sniff_timestamp
  
  d = tuple([address_a, address_b, port_a, port_b])
  entry = hash(d)

  if entry in INDEXES:
    loc = INDEXES.index(entry)
    CONVERSATIONS['bytes'][loc] += int(packet_bytes)
    CONVERSATIONS['packets'][loc] += 1 
    CONVERSATIONS['duration'][loc] = float(packet_timestamp) - float(CONVERSATIONS['start'][loc])

  else:
    INDEXES.append(entry)
    CONVERSATIONS['address_a'].append(address_a)
    CONVERSATIONS['address_b'].append(address_b)
    CONVERSATIONS['port_a'].append(port_a)
    CONVERSATIONS['port_b'].append(port_b)
    CONVERSATIONS['bytes'].append(int(packet_bytes))
    CONVERSATIONS['packets'].append(1)
    CONVERSATIONS['start'].append(float(packet_timestamp))
    CONVERSATIONS['duration'].append(0)

df = pd.DataFrame(CONVERSATIONS)
display(df)
# Out:
#       address_a    address_b port_a port_b  bytes  packets         start  \
# 0    172.28.0.1  172.28.0.12  60550   8080  14190       31  1.677705e+09
# 1   172.28.0.12   172.28.0.1   8080  60550   8275       24  1.677705e+09
# 2    172.28.0.1  172.28.0.12  60560   8080   2426        7  1.677705e+09
# 3   172.28.0.12   172.28.0.1   8080  60560   1173        4  1.677705e+09
# 4   172.28.0.12   172.28.0.1   6000  50258  51026       36  1.677705e+09
# ..          ...          ...    ...    ...    ...      ...           ...
# 83  172.28.0.12   172.28.0.1   8080  58406    623        5  1.677705e+09
# 84   172.28.0.1  172.28.0.12  45274   8080    515        6  1.677705e+09
# 85  172.28.0.12   172.28.0.1   8080  45274   1070        4  1.677705e+09
# 86   172.28.0.1  172.28.0.12  45278   8080   2767        8  1.677705e+09
# 87  172.28.0.12   172.28.0.1   8080  45278   1379        7  1.677705e+09
#
#       duration
# 0    58.396585
# 1    58.396530
# 2     6.574728
# 3     6.573628
# 4   286.857066
# ..         ...
# 83    0.292146
# 84    0.007568
# 85    0.007531
# 86    1.113594
# 87    1.113562
#
# [88 rows x 8 columns]
